# %%
import pandas as pd

# %%
# Load the data set
df=pd.read_csv('abalone.data.csv')

# %%
df
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365     NaN        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010           NaN     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
# Find shape of data set
df.shape
# Out:
# (4177, 9)

# %%
# Summary of data
df.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365     NaN        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0           NaN     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4           NaN      7

# %%
# Summary of data
df.tail()
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12

# %%
# Find data type of each column
df.dtypes
# Out:
# Sex                object
# Length            float64
# Diameter          float64
# Height            float64
# Whole weight      float64
# Shucked weight    float64
# Viscera weight    float64
# Shell weight      float64
# Rings               int64
# dtype: object

# %%
# Find missing values
df.isnull()
# Out:
#         Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0     False   False     False   False         False           False
# 1     False   False     False   False         False           False
# 2     False   False     False   False         False           False
# 3     False   False     False    True         False           False
# 4     False   False     False   False         False           False
# ...     ...     ...       ...     ...           ...             ...
# 4172  False   False     False   False         False           False
# 4173  False   False     False   False         False           False
# 4174  False   False     False   False         False           False
# 4175  False   False     False   False         False           False
# 4176  False   False     False   False         False           False
#
#       Viscera weight  Shell weight  Rings
# 0              False          True  False
# 1              False         False  False
# ...

# %%
df.isnull().sum()
# Out:
# Sex               0
# Length            1
# Diameter          1
# Height            1
# Whole weight      1
# Shucked weight    2
# Viscera weight    0
# Shell weight      3
# Rings             0
# dtype: int64

# %%
# Find out zeroes
df==0
# Out:
#         Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0     False   False     False   False         False           False
# 1     False   False     False   False         False           False
# 2     False   False     False   False         False           False
# 3     False   False     False   False         False           False
# 4     False   False     False   False         False           False
# ...     ...     ...       ...     ...           ...             ...
# 4172  False   False     False   False         False           False
# 4173  False   False     False   False         False           False
# 4174  False   False     False   False         False           False
# 4175  False   False     False   False         False           False
# 4176  False   False     False   False         False           False
#
#       Viscera weight  Shell weight  Rings
# 0              False         False  False
# 1              False         False  False
# ...

# %%
# Finding zeroes
df[df==0]
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0     NaN     NaN       NaN     NaN           NaN             NaN
# 1     NaN     NaN       NaN     NaN           NaN             NaN
# 2     NaN     NaN       NaN     NaN           NaN             NaN
# 3     NaN     NaN       NaN     NaN           NaN             NaN
# 4     NaN     NaN       NaN     NaN           NaN             NaN
# ...   ...     ...       ...     ...           ...             ...
# 4172  NaN     NaN       NaN     NaN           NaN             NaN
# 4173  NaN     NaN       NaN     NaN           NaN             NaN
# 4174  NaN     NaN       NaN     NaN           NaN             NaN
# 4175  NaN     NaN       NaN     NaN           NaN             NaN
# 4176  NaN     NaN       NaN     NaN           NaN             NaN
#
#       Viscera weight  Shell weight  Rings
# 0                NaN           NaN    NaN
# 1                NaN           NaN    NaN
# 2                NaN           NaN    NaN
# ...

# %%
# Sum of zero values in each column
(df==0).sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            2
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %%
# Find mean value of columns containing only numeric data
df.mean(numeric_only=True)
# Out:
# Length            0.523998
# Diameter          0.407865
# Height            0.139520
# Whole weight      0.828716
# Shucked weight    0.359465
# Viscera weight    0.180594
# Shell weight      0.238877
# Rings             9.933684
# dtype: float64

# %%
# Find mean
df['Length'].mean()
# Out:
# 0.5239978448275863

# %%
# Find mean
df['Diameter'].mean()
# Out:
# 0.4078651819923371

# %%
# Find mean
df['Height'].mean()
# Out:
# 0.1395198754789272

# %%
# Find mean
df['Whole weight'].mean()
# Out:
# 0.8287163553639847

# %%
# Find mean
df['Shucked weight'].mean()
# Out:
# 0.35946502994011975

# %%
# Find mean
df['Viscera weight'].mean()
# Out:
# 0.1805936078525257

# %%
# Find mean
df['Shell weight'].mean()
# Out:
# 0.23887673694298037

# %%
# Find mean
df['Rings'].mean()
# Out:
# 9.933684462532918

# %%
# Replace missing values with the column mean 

#df.fillna(df.columns.mean())

# for colName in df.columns:
#     if colName!='Sex':
#         colMean=df[colName].mean()
#         df[colName].fillna(colMean, inplace=True)
#         df.to_csv('updated_data.csv', index=False)
# df

df.fillna(value=df.mean(numeric_only=True), inplace=True)
df
# Out:
#      Sex  Length  Diameter   Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365  0.09500        0.5140          0.2245
# 1      M   0.350     0.265  0.09000        0.2255          0.0995
# 2      F   0.530     0.420  0.13500        0.6770          0.2565
# 3      M   0.440     0.365  0.13952        0.5160          0.2155
# 4      I   0.330     0.255  0.08000        0.2050          0.0895
# ...   ..     ...       ...      ...           ...             ...
# 4172   F   0.565     0.450  0.16500        0.8870          0.3700
# 4173   M   0.590     0.440  0.13500        0.9660          0.4390
# 4174   M   0.600     0.475  0.20500        1.1760          0.5255
# 4175   F   0.625     0.485  0.15000        1.0945          0.5310
# 4176   M   0.710     0.555  0.19500        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010      0.238877     15
# 1             0.0485      0.070000      7
# 2             0.1415      0.210000      9
# ...

# %% [markdown]
# # IMPORTING LIBRARIES

# %%
# Draw pair plot

import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.pairplot(df)

# %%
sns.pairplot(df, hue='Sex')

# %% [markdown]
# # TRAIN TEST SPLIT

# %%
# divide dataset into training set(75%) and testing set(25%)

from sklearn.model_selection import train_test_split

x = df.drop('Rings', axis=1)
y = df['Rings']
x_train, x_test, y_train, y_test = train_test_split(x,y, train_size = 0.75, random_state = 0)    #random_state = 0 means output
                                                                                                 #               doesnt change
print("Shape of data : ", df.shape)
print("x_Train shape : " , x_train.shape)
print("x_Test shape : ", x_test.shape)
print("y_Train shape : ", y_train.shape)
print("y_Test shape : ", y_test.shape)
# Out:
# Shape of data :  (4177, 9)
# x_Train shape :  (3132, 8)
# x_Test shape :  (1045, 8)
# y_Train shape :  (3132,)
# y_Test shape :  (1045,)

# %%
x=df[['Length','Diameter','Shucked weight','Shell weight','Rings']]
x
# Out:
#       Length  Diameter  Shucked weight  Shell weight  Rings
# 0      0.455     0.365          0.2245      0.238877     15
# 1      0.350     0.265          0.0995      0.070000      7
# 2      0.530     0.420          0.2565      0.210000      9
# 3      0.440     0.365          0.2155      0.155000     10
# 4      0.330     0.255          0.0895      0.238877      7
# ...      ...       ...             ...           ...    ...
# 4172   0.565     0.450          0.3700      0.249000     11
# 4173   0.590     0.440          0.4390      0.260500     10
# 4174   0.600     0.475          0.5255      0.308000      9
# 4175   0.625     0.485          0.5310      0.296000     10
# 4176   0.710     0.555          0.9455      0.495000     12
#
# [4177 rows x 5 columns]

# %%
# Display rows with Rings<10 and Sex=F
df[(df['Rings']<10) & (df['Sex']=='F')]
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 23     F   0.550     0.415   0.135        0.7635          0.3180
# 37     F   0.450     0.355   0.105        0.5225          0.2370
# 40     F   0.450     0.335   0.105        0.4250          0.1865
# 47     F   0.460     0.375   0.120        0.4605          0.1775
# ...   ..     ...       ...     ...           ...             ...
# 4117   F   0.640     0.505   0.175        1.3185          0.6185
# 4134   F   0.595     0.455   0.140        0.9140          0.3895
# 4136   F   0.615     0.495   0.155        1.0805          0.5200
# 4159   F   0.560     0.440   0.135        0.8025          0.3500
# 4168   F   0.515     0.400   0.125        0.6150          0.2865
#
#       Viscera weight  Shell weight  Rings
# 2             0.1415        0.2100      9
# 23            0.2100        0.2000      9
# 37            0.1165        0.1450      8
# ...

# %%
df.columns
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight', 'Rings'],
#       dtype='object')
